# %%
# Analysis: Sales Data (Knightbearr)
# referência: https://www.kaggle.com/code/knightbearr/analysis-sales-data-knightbearr

import pandas as pd

# %%
df = pd.read_excel("matr550.xlsx")

# %%
print(df.dtypes)
# Out:
# Cliente                      int64
# Loja                         int64
# Nome                        object
# DT Emissao          datetime64[ns]
# Tipo da nota                object
# Numero                       int64
# Produto                     object
# Descricao                   object
# Quantidade                   int64
# Valor Unitario             float64
# Valor Mercadoria           float64
# Armaz                        int64
# Cfo                          int64
# Tes                          int64
# Pedido                       int64
# It                          object
# Valor IPI                  float64
# Valor Icms                 float64
# Total                      float64
# dtype: object

# %%
# Convert columns for object
df['Cliente'] = df['Cliente'].astype('object')
df['Loja'] = df['Loja'].astype('object')
df['Numero'] = df['Numero'].astype('object')
df['Armaz'] = df['Armaz'].astype('object')
df['Cfo'] = df['Cfo'].astype('object')
df['Pedido'] = df['Pedido'].astype('object')

print(df.dtypes)
# Out:
# Cliente                     object
# Loja                        object
# Nome                        object
# DT Emissao          datetime64[ns]
# Tipo da nota                object
# Numero                      object
# Produto                     object
# Descricao                   object
# Quantidade                   int64
# Valor Unitario             float64
# Valor Mercadoria           float64
# Armaz                       object
# Cfo                         object
# Tes                          int64
# Pedido                      object
# It                          object
# Valor IPI                  float64
# Valor Icms                 float64
# Total                      float64
# dtype: object

# %%
# Incluir uma coluna dom a descrição das TES
df['desc_tes'] = 0

for tes in df['Tes']:    
    df.loc[df['Tes'] == 512, 'desc_tes'] = "512 - REVENDA MERCADORIA NO ARMAZEM"
    df.loc[df['Tes'] == 590, 'desc_tes'] = "590 - REVENDA COM ST"
    df.loc[df['Tes'] == 515, 'desc_tes'] = "515 - VENDA ORGAO PUBLICO SAO PAULO"
    df.loc[df['Tes'] == 520, 'desc_tes'] = "520 - VENDA DE CONSUMO PARA CONTRIBUINTE"
    df.loc[df['Tes'] == 514, 'desc_tes'] = "514 - VENDA ZONA FRANCA"
    df.loc[df['Tes'] == 517, 'desc_tes'] = "517 - REVENDA DE MERCADORIA SAINDO DO ESCRITORIO"
    df.loc[df['Tes'] == 624, 'desc_tes'] = "624 - REMESSA ARMAZEM GERAL"
    df.loc[df['Tes'] == 639, 'desc_tes'] = "639 - BRINDE SP"
    df.loc[df['Tes'] == 631, 'desc_tes'] = "631 - BONIFICAÇAO"
    df.loc[df['Tes'] == 634, 'desc_tes'] = "634 - BONIFICACAO COM ST"
    df.loc[df['Tes'] == 645, 'desc_tes'] = "645 - REMESSA PARA DEMONSTRAÇÃO"
    df.loc[df['Tes'] == 746, 'desc_tes'] = "746 - EMPRESTIMO ATIVO"
    df.loc[df['Tes'] == 711, 'desc_tes'] = "711 - SERVIÇOS PRESTADOS"
    df.loc[df['Tes'] == 710, 'desc_tes'] = "710 - SERVIÇO PRESTADO PARA O EXTERIOR"
    df.loc[df['Tes'] == 690, 'desc_tes'] = "690 - VENDA - SIMPLES FATURAMENTO"
    df.loc[df['Tes'] == 560, 'desc_tes'] = "560 - SIMPLES REMESSA"
    df.loc[df['Tes'] == 615, 'desc_tes'] = "615 - REMESSA ATIVO FORA DO ESTABELECIMENTO"
    df.loc[df['Tes'] == 660, 'desc_tes'] = "660 - REMESSA PARA EXPOSIÇAO"
    df.loc[df['Tes'] == 736, 'desc_tes'] = "736 - REMESSA EM GARANTIA"
    df.loc[df['Tes'] == 721, 'desc_tes'] = "721 - MANUTENÇÃO EM GARANTIA"
    df.loc[df['Tes'] == 735, 'desc_tes'] = "735 - REMESSA EM GARANTIA"
    df.loc[df['Tes'] == 705, 'desc_tes'] = "705 - BAIXA DE ESTOQUE"
    df.loc[df['Tes'] == 521, 'desc_tes'] = "521 - VENDA FORA DO ESTABELECIMENTO"


display(df)
# Out:
#       Cliente Loja                                      Nome DT Emissao  \
# 0           7    1                       LOG 10 EXPRESS LTDA 2019-01-03
# 1           7    1                       LOG 10 EXPRESS LTDA 2019-01-03
# 2           7    1                       LOG 10 EXPRESS LTDA 2019-01-03
# 3           7    1                       LOG 10 EXPRESS LTDA 2019-01-03
# 4           7    1                       LOG 10 EXPRESS LTDA 2019-01-03
# ...       ...  ...                                       ...        ...
# 12737     721    1  ASSOCIAÇÃO CONGREGACAO DE SANTA CATARINA 2022-06-30
# 12738     249    1  UNIMED RONDONIA - COOP.DE TRABALHO MEDIC 2022-06-30
# 12739     249    1  UNIMED RONDONIA - COOP.DE TRABALHO MEDIC 2022-06-30
# 12740     249    1  UNIMED RONDONIA - COOP.DE TRABALHO MEDIC 2022-06-30
# 12741     471    1                  CIRURGICA VALADARES LTDA 2022-06-30
#
#       Tipo da nota Numero         Produto  \
# 0                B   1904           10361
# ...

# %%
# Selecionando linhas com determinadas condições
only_sales512 = df.loc[df['Tes'] == 512 ]
only_sales590 = df.loc[df['Tes'] == 590]
only_sales517 = df.loc[df['Tes'] == 517]
only_sales711 = df.loc[df['Tes'] == 711]
only_sales521 = df.loc[df['Tes'] == 521]

# %%
so_sales = pd.DataFrame()
so_sales = so_sales.append(only_sales512)
so_sales = so_sales.append(only_sales590)
so_sales = so_sales.append(only_sales517)
so_sales = so_sales.append(only_sales711)
so_sales = so_sales.append(only_sales521)

display(so_sales)
# Out:
# /tmp/ipykernel_38259/1129725202.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   so_sales = so_sales.append(only_sales512)
# /tmp/ipykernel_38259/1129725202.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   so_sales = so_sales.append(only_sales590)
# /tmp/ipykernel_38259/1129725202.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   so_sales = so_sales.append(only_sales517)
# /tmp/ipykernel_38259/1129725202.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   so_sales = so_sales.append(only_sales711)
# ...

# %%
# Inlcuir colunas com o mês e o ano

so_sales['Ano'] = so_sales['DT Emissao'].dt.strftime('%Y')
so_sales['Mes'] = so_sales['DT Emissao'].dt.strftime('%m')

display(so_sales)
# Out:
#       Cliente Loja                                      Nome DT Emissao  \
# 1560      262    1  NORDESTE MEDICAL, REPRESENTACAO, IMPORTA 2019-01-08
# 1561      262    1  NORDESTE MEDICAL, REPRESENTACAO, IMPORTA 2019-01-08
# 1562      262    1  NORDESTE MEDICAL, REPRESENTACAO, IMPORTA 2019-01-08
# 1563      262    1  NORDESTE MEDICAL, REPRESENTACAO, IMPORTA 2019-01-08
# 1564        7    1   ALVES LOPES COMERCIO & SERVICOS EIRELLI 2019-01-08
# ...       ...  ...                                       ...        ...
# 12602     712    1                      WANNER SILVA VILLACA 2022-06-18
# 12603     708    1                     MIRALDO PEREIRA MATOS 2022-06-18
# 12604     716    1                MAXIMO CARLOS SANZ DELGADO 2022-06-18
# 12605     716    1                MAXIMO CARLOS SANZ DELGADO 2022-06-18
# 12606     716    1                MAXIMO CARLOS SANZ DELGADO 2022-06-18
#
#       Tipo da nota Numero         Produto  \
# 1560             N   1923    2056-200.100
# ...

# %%
# Ordenar coluna

so_sales = so_sales[['Cliente', 'Loja', 'Nome', 'Numero', 'DT Emissao', 'Ano', 'Mes','Tipo da nota', 'Produto', 'Descricao', 'Quantidade', 'Valor Unitario', 'Valor Mercadoria', 'Armaz', 'Cfo', 'Tes', 'desc_tes', 'Pedido', 'It', 'Valor IPI', 'Valor Icms', 'Total']]

print(so_sales.columns)
# Out:
# Index(['Cliente', 'Loja', 'Nome', 'Numero', 'DT Emissao', 'Ano', 'Mes',
#        'Tipo da nota', 'Produto', 'Descricao', 'Quantidade', 'Valor Unitario',
#        'Valor Mercadoria', 'Armaz', 'Cfo', 'Tes', 'desc_tes', 'Pedido', 'It',
#        'Valor IPI', 'Valor Icms', 'Total'],
#       dtype='object')

# %%
# Soma das colunas
print(df['Total'].sum())
print(so_sales['Total'].sum())
# Out:
# 28486534.94
# 9686134.35

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.figure(figsize=(24, 8))
sns.heatmap(so_sales.corr(), annot=True, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
import numpy as np

# %%
sales_data_numeric = so_sales.describe(include=[np.number])
sales_data_numeric
# Out:
#         Quantidade  Valor Unitario  Valor Mercadoria          Tes  \
# count  9318.000000     9318.000000       9318.000000  9318.000000
# mean      3.693175      419.727707        962.503677   515.117944
# std      13.906848     1110.884585       2887.741329    22.652755
# min       1.000000        1.000000          1.000000   512.000000
# 25%       1.000000      184.810000        204.970000   512.000000
# 50%       1.000000      255.660000        302.600000   512.000000
# 75%       1.000000      427.696700        591.630000   512.000000
# max     550.000000    46983.090000     109745.920000   711.000000
#
#          Valor IPI   Valor Icms          Total
# count  9318.000000  9318.000000    9318.000000
# mean     76.160824    54.717815    1039.507872
# std     228.380625   236.140128    3109.326685
# min       0.000000     0.000000       1.000000
# 25%      16.040000     8.200000     221.370000
# 50%      23.930000    12.320000     332.550000
# ...

# %%
sales_data_object = so_sales.describe(exclude=[np.number])
sales_data_object
# Out:
# /tmp/ipykernel_38259/1629091684.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   sales_data_object = so_sales.describe(exclude=[np.number])
#         Cliente    Loja                                     Nome  Numero  \
# count    9318.0  9318.0                                     9318  9318.0
# unique    313.0     3.0                                      310  1417.0
# top       114.0     1.0  HDNM COMERCIO DE MATERIAIS HOSPITALARES  2984.0
# freq     1300.0  9244.0                                     1300    99.0
# first       NaN     NaN                                      NaN     NaN
# last        NaN     NaN                                      NaN     NaN
#
#                  DT Emissao   Ano   Mes Tipo da nota       Produto  \
# ...

# %%
from statsmodels.graphics.gofplots import qqplot

# %%
# checking and visualizing the type of distribution of a feature column
def univariate_analysis(data, color, title1, title2):
    
    """
    Showing visualization of univariate
    analysis with displot and qqplot
    visualization from seaborn and statsmodel
    library.
    
    Parameters
    ----------
    data : DataFrame, array, or list of arrays, optional
        Dataset for plotting. If ``x`` and ``y`` are absent, this is
        interpreted as wide-form. Otherwise it is expected to be long-form. 
    title1: The title of the visualization, title1 for displot visualization
        And title2 for quantile plot from statsmodel.
    title2: The title of the visualization, title1 for displot visualization
        And title2 for quantile plot from statsmodel.
        
    Returns
    -------
    fig : matplotlib figure
        Returns the Figure object with the plot drawn onto it.
    """
    
    fig, (ax1, ax2) = plt.subplots( # subplots
        ncols=2, # num of cols
        nrows=1, # num of rows
        figsize=(20, 6) # set the width and high
    )

    sns.distplot( # create a distplot visualization
        data, # data
        ax=ax1, # axes 1
        kde=True, # kde
        color=color # color
    )
    
    ax1.set_title( # set the title 1
        title1, 
        weight="bold", # weight
        fontsize=25, # font-size
        pad=30 # padding
    ) 
    
    qqplot( # qqplot (quantile plot)
        data, # data
        ax=ax2, # axes 2
        line='s' # line 
    )
    
    ax2.set_title( # set the title 2
        title2, 
        weight="bold", # weight
        fontsize=25, # font-size
        pad=30 # padding
    )
    
    return fig # returning the figure

# %%
# Quantity Ordered Data
univariate_analysis( # call the function
    data=so_sales['Quantidade'], # put the data
    color='red', # pick the color
    title1='Quantity Ordered Data Distribution', # title1
    title2='Quantile Plot' # title2
)
# Out:
# /home/luciano/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Price Each Data
univariate_analysis( # call the function
    data=so_sales['Valor Unitario'], # put the data
    color='blue', # pick the color 
    title1='Price Each Data Distribution', # title1 
    title2='Quantile Plot' # title2
)
# Out:
# /home/luciano/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Sales Data
univariate_analysis( # call the function
    data=so_sales['Total'], # put the data 
    color='black', # pick the color
    title1='Sales Data Distribution', # title1 
    title2='Quantile Plot' # title2
)
# Out:
# /home/luciano/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# checking skewness value (Valor de assimetria)
# if value lies between -0.5 to 0.5  then it is normal otherwise skewed
skew_value = so_sales.skew().sort_values(ascending=False).to_frame()
skew_value
# Out:
# /tmp/ipykernel_38259/1223078412.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   skew_value = so_sales.skew().sort_values(ascending=False).to_frame()
#                           0
# Valor Unitario    19.021165
# Quantidade        17.135804
# Valor Icms        14.856806
# Valor IPI         14.512115
# Total             14.343371
# Valor Mercadoria  14.330231
# Tes                8.258697
# Armaz              7.244749
# It                 2.799082
# Cliente            1.286441
# Ano                0.516350
# Mes                0.418809
# Pedido             0.266095
# Numero            -0.224649
# Cfo               -3.302568
# Loja              -4.450336

# %%
# let's plot it
plt.figure(figsize=(24, 8)) # figuring the size
# makes count plot 
sns.countplot(
    x="Ano", 
    data=so_sales
)
plt.title( # title
    "What was the best Year for sales? How much was earned that Year?", 
    weight="bold", # weiqht
    fontsize=35, # font-size
    pad=30 # padding
)
plt.xlabel( # x-label
    "Years", 
    weight="bold", # weight
    color="purple", # color
    fontsize=25, # font-size
    loc="center" # location
)
plt.xticks( # x-ticks
    weight="bold", # weight
    fontsize=15 # font-size
)
plt.ylabel( # y-label
    "Sales in BRL (R$)", 
    weight="bold", # weight
    color="green", # color
    fontsize=20 # font-size
)
plt.yticks( # y-ticks
    weight="bold", # weight 
    fontsize=15 # font-size
)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# group the Month cols
sum_of_month_and_earned = so_sales.groupby('Mes').sum().astype('int')
# let's plot it
plt.figure(figsize=(24, 14)) # figuring the size
# makes bar plot 
sns.barplot( # barplot
    x=sum_of_month_and_earned.index, # x-axis
    y=sum_of_month_and_earned["Total"], # y-axis
    data=sum_of_month_and_earned, # data
    palette="deep" # palette
)
plt.title( # title
    "What was the best month for sales? How much was earned that month?", 
    weight="bold", # weight
    fontsize=35, # font-size
    pad=30 # padding
)
plt.xlabel( # x-label
    "Months", 
    weight="bold", # weight
    color="purple", # color
    fontsize=15, # font-size
    loc="center" # location
)
plt.xticks( # x-ticks
    weight="bold", # weight
    fontsize=15 # font-size
)
plt.ylabel( # y-label
    "Sales in Reais (R$)", 
    weight="bold", # weight
    color="green", # color
    fontsize=20 # font-size
)
plt.yticks( # y-ticks
    weight="bold", # weight 
    fontsize=15 # font-size
)
# Out:
# (array([      0.,  200000.,  400000.,  600000.,  800000., 1000000.,
#         1200000., 1400000., 1600000., 1800000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# What products are most often sold together?

from itertools import combinations
from collections import Counter

# drop it using duplicated() funct
data = so_sales[so_sales['Numero'].duplicated(keep=False)]
# create a new column
data['Grouped'] = so_sales.groupby('Numero')['Produto'].transform(lambda x: ','.join(x))
# let's make a new variable
data = data[['Produto', 'Grouped']].drop_duplicates()
# create a new variable for Counter
count = Counter()
# make a for loop
for row in data['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))
# and make another for loop    
for key, value in count.most_common(10):
    print(key, value)
# Out:
# /tmp/ipykernel_38259/433887377.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Grouped'] = so_sales.groupby('Numero')['Produto'].transform(lambda x: ','.join(x))
# ('LF1459-151.100', 'LF1459-151.100') 127978
# ('1251-150.100', '1251-150.100') 48237
# ('LF1468-151.100', 'LF1468-151.100') 34885
# ('LF1350-151.100', 'LF1350-151.100') 26589
# ('1251-152.100', '1251-152.100') 25216
# ('LF1350-155.100', 'LF1350-155.100') 21621
# ('1251-150.100', 'LF1459-151.100') 20149
# ('LF1459-151.100', 'LF1468-151.100') 11011
# ('1251-150.100', '3650-300.100') 10854
# ('1512-150.100', '1517-150.100') 10123

# %%
# Nesse caso acima não deu certo pq os produtos que contém numero de serie acabou se destacando, pois são vendidos de um em um por NF.

# %%
# What product sold the most? Why do you think it sold the most?
# new_so_sales = so_sales.groupby(by=['Produto']).sum().sort_values(by='Quantidade', ascending=False)

group_products = so_sales.groupby('Produto')
qty_sales_nfs = group_products.sum()['Quantidade']
prices = so_sales.groupby('Produto').mean()['Valor Unitario']
products = [product for product, x in group_products]

"""Visualization"""
# let's make a subplots
fig, ax1 = plt.subplots(figsize=(24, 14))
ax2 = ax1.twinx()
# AXES 1
ax1.bar(products, qty_sales_nfs)
ax1.set_title( # title
    "What product sold the most? Why do you think it sold the most?",
    weight="bold", # weight
    fontsize=35, # font-size
    pad=30 # padding
)
ax1.set_xlabel( # x-label
    "Product Names",
    weight="bold", # weight
    fontsize=25, # font-size
    color="black" # color
)
ax1.set_ylabel( # y-label
    "Quantity Ordered", 
    color="blue", # color
    fontsize=20, # font-size
    weight="bold" # weight
)
ax1.set_xticklabels( # x-ticks
    products, # ticks
    rotation="vertical", # rotation 
    weight="bold" # weight
)
# AXES 2
sns.lineplot( # plot
    products, # x-axis
    prices, # y-axis
    color="red"
)
ax2.set_ylabel( # y-label
    "Price in BRL (R$)", 
    color="green", # color
    fontsize=20, # font-size
    weight="bold" # weight
)
# Out:
# /tmp/ipykernel_38259/2086748799.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels( # x-ticks
# /home/luciano/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Price in BRL (R$)')

# %%
#  Preciso aprender a filtrar só com os principais produtos e plotar, isso irá melhorar a vizualização.

# %%
df.columns
# Out:
# Index(['Cliente', 'Loja', 'Nome', 'DT Emissao', 'Tipo da nota', 'Numero',
#        'Produto', 'Descricao', 'Quantidade', 'Valor Unitario',
#        'Valor Mercadoria', 'Armaz', 'Cfo', 'Tes', 'Pedido', 'It', 'Valor IPI',
#        'Valor Icms', 'Total', 'desc_tes'],
#       dtype='object')
